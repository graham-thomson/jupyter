# %%
# %matplotlib inline
import matplotlib as plt
import seaborn as sns
import pandas as pd
import psycopg2 as psql

conn = psql.connect("user=gthomson password=summer15 dbname=com_db host=comcast.digitas.com")
sql = """SELECT
	load_date::timestamp,
	COUNT(*)
FROM
	adobe_data.performance_report
WHERE
	load_date > '2016-07-15'
GROUP BY
	1
ORDER BY
	1"""

data = pd.read_sql(sql=sql, con=conn)

print data.head()
# Out:
#    load_date   count
# 0 2016-07-16  703557
# 1 2016-07-17  681488
# 2 2016-07-18  673871
# 3 2016-07-19  720925
# 4 2016-07-20  720302

# %%
data.describe()
# Out:
#                count
# count      54.000000
# mean   733681.555556
# std    158278.110492
# min      9642.000000
# 25%    721214.750000
# 50%    751758.500000
# 75%    805821.750000
# max    902001.000000

# %%
# sns.barplot(x=data.index.values, y="count", data=data, color='r')

import matplotlib.pyplot as plt
ax = plt.subplot()
ax.set_title("Row Count Distribution")
sns.distplot(data['count'], color='g', ax=ax)

# %%
sns.barplot(x=data.index.values, y='count', data=data, color='g')
